# %%
# -*- coding: utf-8 -*- 

import tkinter as tk
import glob
from PIL import Image, ImageTk


dpartment=[100,120,121,150,220,223,310,325,330,350,750,756,760,570,160,510,530]




def read_train_object():
    train_name = open('/home/vincent/facenet/models/name.txt','r') 
    
    lines = train_name.readlines()
    count=0
    for a in lines:
        b=a.split('\n')
        lines[count]=b[0]
        count += 1
    train_name.close
    return lines


def person_pd_ID():
    allname=read_train_object()
    print(allname)
    name123=[]
    number123=[]
    pd123=[]
    for a in allname:
        print(a)
        all_23=a.split("_")
        print(all_23)
        number15=all_23[0]
        name15=all_23[1]
        pd15=all_23[2]
        number123.append(number15)
        name123.append(name15)
        pd123.append(pd15)

    print(name123)
    print(number123)
    print(pd123)

    persenID = dict(zip(number123, name123))
    pdID = dict(zip(number123, pd123))
    fullID=dict(zip(number123,allname) )
    print(persenID)
    print(pdID)
    return number123,persenID,pdID,fullID





class mainpage(object):
    def __init__(self, master=None):
        self.root = master 
        
        self.page = tk.Frame(self.root) 
        self.page.grid()
        self.Button = tk.Button(self.page, text=u'DP100總經理室', font=('Arial', 12),justify = tk.LEFT,command=self.secpage) 
        self.Button.grid(column=0,row=0, sticky=tk.W) 
        self.Button = tk.Button(self.page, text=u'DP760軟體', font=('Arial', 12),justify = tk.LEFT,command=self.th3page) 
        self.Button.grid(column=1,row=0,sticky=tk.W) 
        
        
        spaceLabel= tk.Label(self.page,textvariable="             " )
        spaceLabel.grid(column=0, row=1, sticky=tk.W)

        #從資料夾抓取以建檔名稱
        filename=[]
        sourcefile=glob.glob(r'../datasets/personout/*')
        print('sourcefile',sourcefile)
        for a in sourcefile:
            finalname=a.split("/")
            filename.append(finalname[-1])
        print ('finalname',filename)
        print('len(filename',len(filename))
        line1=2

        for dpart in dpartment:

            print('dpartment',dpart)
            locals()['self.var'+str(dpart)]=tk.StringVar()
            locals()['self.var'+str(dpart)].set(str(dpart)+'部門:  ')
        #         locals()['textLabel'+str(dpart)] = tk.Label(window,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12), width=30, height=2,justify = tk.LEFT)#显示文字内容 
            locals()['self.textLabel'+str(dpart)] = tk.Label(self.page,textvariable=locals()['self.var'+str(dpart)], bg='green', font=('Arial', 12),justify = tk.LEFT)#显示文字内容
            locals()['self.textLabel'+str(dpart)].grid(column=0, row=line1, sticky=tk.W) #自动对齐,side：方位

        #         line1=line1+1
            print('line1',line1)
            gpart=[]
            for c,v in pdID.items():
                if str(v)==str(dpart):
                    gpart.append(c)
                    print('number',c)
            column01=1
            for personq in gpart:
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['self.var'+str(personq)]=tk.StringVar()
                locals()['self.var'+str(personq)].set(persenID[personq])
                locals()['self.textLabel'+str(personq)] = tk.Label(self.page,textvariable=locals()['self.var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['self.textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1
    #                 if column01==len(gpart)-1:
    #                     line1=line1+1

            line1=line1+1 
#             column01=1
            
#             for imagep in gpart:
#                 print('fullID[imagep]',fullID[imagep])
#                 print('imagep',imagep)
#                 try:
#                     file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*001.png')
#                 except:
#                     file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*.png')
#                 print('file_resize',file_resize)
                
                
# #                 pil_image = Image.open(r'C:\Users\23216\Desktop\1.jpg') 
                
# #                 realname=file_resize[0].split('/')
#                 print("file_resize[-1]",file_resize[-1])
#                 locals()['photo'+str(imagep)] = tk.PhotoImage(file=file_resize[0])  #file：t图片路径
#                 locals()['imgLabel'+str(imagep)]  = tk.Label(self.page,image=locals()['photo'+str(imagep)])#把图片整合到标签类中
#                 locals()['imgLabel'+str(imagep)].grid(column=column01, row=line1, sticky=tk.W)
#                 column01=column01+1
        
        
#         root.mainloop()   

        
        
        

    def secpage(self):
        self.page.destroy()
        secondpage(self.root)
        
        
    def th3page(self):
        self.page.destroy()
        th3page(self.root)
    
class secondpage(object):
    def __init__(self, master=None):
        self.root = master
        self.page = tk.Frame(self.root)
        self.page.grid()
 
        self.Button = tk.Button(self.page, text=u'主頁',font=('Arial', 12),justify = tk.LEFT,command=self.mainpage) 
        self.Button.grid(column=0,row=0, sticky=tk.W) 
        
        
        spaceLabel= tk.Label(self.page,textvariable="             " )
        spaceLabel.grid(column=0, row=1, sticky=tk.W)
        
        varspace=tk.StringVar()
        varspace.set("部門人員建制名單")
        spaceLabel= tk.Label(self.page,textvariable=varspace, font=('Arial', 12),justify = tk.LEFT )
        spaceLabel.grid(column=0, row=2, sticky=tk.W)
        
        
        line1=3
        gpart=[]
        for c,v in pdID.items():
            if str(v)==str(100):
                gpart.append(c)
                print('number',c)
        column01=0
        for personq in gpart:
            
            if len(gpart)>5:
            
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['self.var'+str(personq)]=tk.StringVar()
                locals()['self.var'+str(personq)].set(personq+' '+persenID[personq])
                locals()['self.textLabel'+str(personq)] = tk.Label(self.page,textvariable=locals()['self.var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['self.textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1
                if column01==4:
                    line1=line1+2
                    column01=0
                    
            if len(gpart)<5:
            
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['self.var'+str(personq)]=tk.StringVar()
                locals()['self.var'+str(personq)].set(personq+' '+persenID[personq])
                locals()['self.textLabel'+str(personq)] = tk.Label(self.page,textvariable=locals()['self.var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['self.textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1

        line1=4
        column01=0
            
        for imagep in gpart:
            
            if len(gpart)>5:
            
            
                print('fullID[imagep]',fullID[imagep])
                print('imagep',imagep)
                try:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*001.png')
                except:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*.png')
                print('file_resize',file_resize)


#                 pil_image = Image.open(r'C:\Users\23216\Desktop\1.jpg') 

#                 realname=file_resize[0].split('/')
                print("file_resize[-1]",file_resize[-1])
                locals()['photo'+str(imagep)] = tk.PhotoImage(file=file_resize[-1])  #file：t图片路径
                locals()['imgLabel'+str(imagep)]  = tk.Label(self.page,image=locals()['photo'+str(imagep)])#把图片整合到标签类中
                locals()['imgLabel'+str(imagep)].grid(column=column01, row=line1, sticky=tk.W)
                column01=column01+1
                if column01==4:
                    line1=line1+2
                    column01=0
                    
            if len(gpart)<5:
                
                print('fullID[imagep]',fullID[imagep])
                print('imagep',imagep)
                try:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*001.png')
                except:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*.png')
                print('file_resize',file_resize)


#                 pil_image = Image.open(r'C:\Users\23216\Desktop\1.jpg') 

#                 realname=file_resize[0].split('/')
                print("file_resize[-1]",file_resize[-1])
                locals()['photo'+str(imagep)] = tk.PhotoImage(file=file_resize[-1])  #file：t图片路径
                locals()['imgLabel'+str(imagep)]  = tk.Label(self.page,image=locals()['photo'+str(imagep)])#把图片整合到标签类中
                locals()['imgLabel'+str(imagep)].grid(column=column01, row=line1, sticky=tk.W)
                column01=column01+1
        
        
        root.mainloop()   
    
    
    
    def mainpage(self):
        self.page.destroy()
        mainpage(self.root)
        
        
        
        
class th3page(object):
    def __init__(self, master=None):
        self.root = master
        self.page = tk.Frame(self.root)
        self.page.grid()
 
        self.Button = tk.Button(self.page, text=u'主頁',font=('Arial', 12),justify = tk.LEFT,command=self.mainpage) 
        self.Button.grid(column=0,row=0) 
        
        
        spaceLabel= tk.Label(self.page,textvariable="             " )
        spaceLabel.grid(column=0, row=1, sticky=tk.W)
        
        varspace=tk.StringVar()
        varspace.set("部門人員建制名單")
        spaceLabel= tk.Label(self.page,textvariable=varspace, font=('Arial', 12),justify = tk.LEFT )
        spaceLabel.grid(column=0, row=2, sticky=tk.W)
        
        
        line1=3
        gpart=[]
        for c,v in pdID.items():
            if str(v)==str(760):
                gpart.append(c)
                print('number',c)
        column01=0
        for personq in gpart:
            
            if len(gpart)>5:
            
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['self.var'+str(personq)]=tk.StringVar()
                locals()['self.var'+str(personq)].set(personq+' '+persenID[personq])
                locals()['self.textLabel'+str(personq)] = tk.Label(self.page,textvariable=locals()['self.var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['self.textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1
                if column01==4:
                    line1=line1+2
                    column01=0
                    
            if len(gpart)<5:
            
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['self.var'+str(personq)]=tk.StringVar()
                locals()['self.var'+str(personq)].set(personq+' '+persenID[personq])
                locals()['self.textLabel'+str(personq)] = tk.Label(self.page,textvariable=locals()['self.var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['self.textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1

        line1=4
        column01=0
            
        for imagep in gpart:
            
            if len(gpart)>5:
            
            
                print('fullID[imagep]',fullID[imagep])
                print('imagep',imagep)
                try:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*001.png')
                except:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*.png')
                print('file_resize',file_resize)


#                 pil_image = Image.open(r'C:\Users\23216\Desktop\1.jpg') 

#                 realname=file_resize[0].split('/')
                print("file_resize[-1]",file_resize[-1])
                locals()['photo'+str(imagep)] = tk.PhotoImage(file=file_resize[0])  #file：t图片路径
                locals()['imgLabel'+str(imagep)]  = tk.Label(self.page,image=locals()['photo'+str(imagep)])#把图片整合到标签类中
                locals()['imgLabel'+str(imagep)].grid(column=column01, row=line1, sticky=tk.W)
                column01=column01+1
                if column01==4:
                    line1=line1+2
                    column01=0
                    
            if len(gpart)<5:
                
                print('fullID[imagep]',fullID[imagep])
                print('imagep',imagep)
                try:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*001.png')
                except:
                    file_resize=glob.glob(r'../datasets/personout/'+fullID[imagep]+'/*.png')
                print('file_resize',file_resize)


#                 pil_image = Image.open(r'C:\Users\23216\Desktop\1.jpg') 

#                 realname=file_resize[0].split('/')
                print("file_resize[-1]",file_resize[-1])
                locals()['photo'+str(imagep)] = tk.PhotoImage(file=file_resize[0])  #file：t图片路径
                locals()['imgLabel'+str(imagep)]  = tk.Label(self.page,image=locals()['photo'+str(imagep)])#把图片整合到标签类中
                locals()['imgLabel'+str(imagep)].grid(column=column01, row=line1, sticky=tk.W)
                column01=column01+1
        
        
        root.mainloop()   
        
    def mainpage(self):
        self.page.destroy()
        mainpage(self.root)

        
def fff():
    o=th3page()
    o.page.destroy(root)


    
number123,persenID,pdID,fullID =person_pd_ID()    



root = tk.Tk()
# root = tk.Toplevel()
# https://blog.csdn.net/FunkyPants/article/details/78163021


root.title('撼訊科技 門禁管理系統')
root.geometry('800x600')

menubar = tk.Menu(root)
filemenu = tk.Menu(menubar, tearoff=0)

menubar.add_cascade(label='開始', menu=filemenu)

# 在File中加入New、Open、Save等小菜单，即我们平时看到的下拉菜单，每一个小菜单对应命令操作。
filemenu.add_command(label='員工資料建立', command=fff  )
filemenu.add_command(label='出缺勤管理', command=fff)
filemenu.add_command(label='後台管理', command=fff)
filemenu.add_separator()    # 添加一条分隔线
filemenu.add_command(label='Exit', command=root.quit) # 用tkinter里面自带的quit()函数

# 第7步，创建一个Edit菜单项（默认不下拉，下拉内容包括Cut，Copy，Paste功能项）
editmenu = tk.Menu(menubar, tearoff=0)
# 将上面定义的空菜单命名为 Edit，放在菜单栏中，就是装入那个容器中
menubar.add_cascade(label='執行', menu=editmenu)

# 同样的在 Edit 中加入Cut、Copy、Paste等小命令功能单元，如果点击这些单元, 就会触发do_job的功能
editmenu.add_command(label='門禁系統啟動', command=fff)
editmenu.add_command(label='出缺勤紀錄日報表', command=fff)
editmenu.add_command(label='陌生人管理', command=fff)

# 第8步，创建第二级菜单，即菜单项里面的菜单
submenu = tk.Menu(filemenu) # 和上面定义菜单一样，不过此处实在File上创建一个空的菜单
filemenu.add_cascade(label='Import', menu=submenu, underline=0) # 给放入的菜单submenu命名为Import

# 第9步，创建第三级菜单命令，即菜单项里面的菜单项里面的菜单命令（有点拗口，笑~~~）
submenu.add_command(label='Submenu_1', command=fff)   # 这里和上面创建原理也一样，在Import菜单项中加入一个小菜单命令Submenu_1

# 第11步，创建菜单栏完成后，配置让菜单栏menubar显示出来
root.config(menu=menubar)

mainpage(root)

root.mainloop()
# Out:
# ['000101_Andrew_330', '010601_Jessie_510', '020401_Ken_756', '020403_Jerry_756', '020404_Rala_756', '020406_James_756', '020411_Richard_330', '020412_Robert_310', '020416_Kay_756', '020501_Forbes_760', '030704_Vincent_760', '031203_Mark_760', '040604_Allen_760', '040605_Rick_310', '040607_Nicolaes_230', '040701_Jackie_756', '050101_PeiZhong_530', '050402_Catherine_310', '050702_Peter_750', '051101_Jacky_330', '060402_Abby_350', '060601_Iona_150', '060602_Eson_756', '070301_William_750', '070302_Mei_100', '070401_Alex_100', '070601_Ching_310', '070802_Jacky_121', '070903_Tony_121', '070905_Stanley_325', '080101_Fiona_310', '861001_Ted_100', '861007_Kuan_570', '861204_Freeman_750', '870202_R4Lai_570', '890302_David_760', '890503_Wayne_750', '890602_Willy_215', '891001_Willie_325', '900106_Danny_750', '900211_Carol_510', '910901_Bryan_100', '920502_Kelin_350', '920705_Diego_760', '920803_Gillian_310', '921003_Vinie_120', '930704_Jimmy_750', '930909_Mandy_530', '940204_Vivi_215', '940208_Jerry_150', '960701_Vado_230', '960703_Sam_760']
# 000101_Andrew_330
# ['000101', 'Andrew', '330']
# 010601_Jessie_510
# ['010601', 'Jessie', '510']
# 020401_Ken_756
# ['020401', 'Ken', '756']
# 020403_Jerry_756
# ['020403', 'Jerry', '756']
# 020404_Rala_756
# ['020404', 'Rala', '756']
# 020406_James_756
# ['020406', 'James', '756']
# 020411_Richard_330
# ['020411', 'Richard', '330']
# 020412_Robert_310
# ['020412', 'Robert', '310']
# 020416_Kay_756
# ['020416', 'Kay', '756']
# 020501_Forbes_760
# ['020501', 'Forbes', '760']
# 030704_Vincent_760
# ['030704', 'Vincent', '760']
# 031203_Mark_760
# ['031203', 'Mark', '760']
# 040604_Allen_760
# ['040604', 'Allen', '760']
# 040605_Rick_310
# ['040605', 'Rick', '310']
# 040607_Nicolaes_230
# ['040607', 'Nicolaes', '230']
# 040701_Jackie_756
# ['040701', 'Jackie', '756']
# 050101_PeiZhong_530
# ['050101', 'PeiZhong', '530']
# 050402_Catherine_310
# ['050402', 'Catherine', '310']
# 050702_Peter_750
# ['050702', 'Peter', '750']
# 051101_Jacky_330
# ['051101', 'Jacky', '330']
# 060402_Abby_350
# ['060402', 'Abby', '350']
# 060601_Iona_150
# ['060601', 'Iona', '150']
# 060602_Eson_756
# ['060602', 'Eson', '756']
# 070301_William_750
# ['070301', 'William', '750']
# 070302_Mei_100
# ['070302', 'Mei', '100']
# 070401_Alex_100
# ['070401', 'Alex', '100']
# 070601_Ching_310
# ['070601', 'Ching', '310']
# 070802_Jacky_121
# ['070802', 'Jacky', '121']
# 070903_Tony_121
# ['070903', 'Tony', '121']
# 070905_Stanley_325
# ['070905', 'Stanley', '325']
# 080101_Fiona_310
# ['080101', 'Fiona', '310']
# 861001_Ted_100
# ['861001', 'Ted', '100']
# 861007_Kuan_570
# ['861007', 'Kuan', '570']
# 861204_Freeman_750
# ['861204', 'Freeman', '750']
# 870202_R4Lai_570
# ['870202', 'R4Lai', '570']
# 890302_David_760
# ['890302', 'David', '760']
# 890503_Wayne_750
# ['890503', 'Wayne', '750']
# 890602_Willy_215
# ['890602', 'Willy', '215']
# 891001_Willie_325
# ['891001', 'Willie', '325']
# 900106_Danny_750
# ['900106', 'Danny', '750']
# 900211_Carol_510
# ['900211', 'Carol', '510']
# 910901_Bryan_100
# ['910901', 'Bryan', '100']
# 920502_Kelin_350
# ['920502', 'Kelin', '350']
# 920705_Diego_760
# ['920705', 'Diego', '760']
# 920803_Gillian_310
# ['920803', 'Gillian', '310']
# 921003_Vinie_120
# ['921003', 'Vinie', '120']
# 930704_Jimmy_750
# ['930704', 'Jimmy', '750']
# 930909_Mandy_530
# ['930909', 'Mandy', '530']
# 940204_Vivi_215
# ['940204', 'Vivi', '215']
# 940208_Jerry_150
# ['940208', 'Jerry', '150']
# 960701_Vado_230
# ['960701', 'Vado', '230']
# 960703_Sam_760
# ['960703', 'Sam', '760']
# ['Andrew', 'Jessie', 'Ken', 'Jerry', 'Rala', 'James', 'Richard', 'Robert', 'Kay', 'Forbes', 'Vincent', 'Mark', 'Allen', 'Rick', 'Nicolaes', 'Jackie', 'PeiZhong', 'Catherine', 'Peter', 'Jacky', 'Abby', 'Iona', 'Eson', 'William', 'Mei', 'Alex', 'Ching', 'Jacky', 'Tony', 'Stanley', 'Fiona', 'Ted', 'Kuan', 'Freeman', 'R4Lai', 'David', 'Wayne', 'Willy', 'Willie', 'Danny', 'Carol', 'Bryan', 'Kelin', 'Diego', 'Gillian', 'Vinie', 'Jimmy', 'Mandy', 'Vivi', 'Jerry', 'Vado', 'Sam']
# ['000101', '010601', '020401', '020403', '020404', '020406', '020411', '020412', '020416', '020501', '030704', '031203', '040604', '040605', '040607', '040701', '050101', '050402', '050702', '051101', '060402', '060601', '060602', '070301', '070302', '070401', '070601', '070802', '070903', '070905', '080101', '861001', '861007', '861204', '870202', '890302', '890503', '890602', '891001', '900106', '900211', '910901', '920502', '920705', '920803', '921003', '930704', '930909', '940204', '940208', '960701', '960703']
# ['330', '510', '756', '756', '756', '756', '330', '310', '756', '760', '760', '760', '760', '310', '230', '756', '530', '310', '750', '330', '350', '150', '756', '750', '100', '100', '310', '121', '121', '325', '310', '100', '570', '750', '570', '760', '750', '215', '325', '750', '510', '100', '350', '760', '310', '120', '750', '530', '215', '150', '230', '760']
# {'960703': 'Sam', '040701': 'Jackie', '910901': 'Bryan', '940204': 'Vivi', '070401': 'Alex', '891001': 'Willie', '050101': 'PeiZhong', '920502': 'Kelin', '060402': 'Abby', '020406': 'James', '861001': 'Ted', '060602': 'Eson', '921003': 'Vinie', '070301': 'William', '020411': 'Richard', '020412': 'Robert', '920705': 'Diego', '900211': 'Carol', '050702': 'Peter', '960701': 'Vado', '020501': 'Forbes', '040605': 'Rick', '051101': 'Jacky', '000101': 'Andrew', '861204': 'Freeman', '070601': 'Ching', '080101': 'Fiona', '940208': 'Jerry', '890602': 'Willy', '070905': 'Stanley', '060601': 'Iona', '930704': 'Jimmy', '030704': 'Vincent', '040607': 'Nicolaes', '920803': 'Gillian', '070802': 'Jacky', '861007': 'Kuan', '020403': 'Jerry', '890302': 'David', '020416': 'Kay', '930909': 'Mandy', '050402': 'Catherine', '010601': 'Jessie', '870202': 'R4Lai', '900106': 'Danny', '020401': 'Ken', '070903': 'Tony', '020404': 'Rala', '070302': 'Mei', '031203': 'Mark', '890503': 'Wayne', '040604': 'Allen'}
# {'960703': '760', '040701': '756', '910901': '100', '940204': '215', '070401': '100', '891001': '325', '050101': '530', '920502': '350', '060402': '350', '020406': '756', '861001': '100', '060602': '756', '921003': '120', '070301': '750', '020411': '330', '020412': '310', '920705': '760', '900211': '510', '050702': '750', '960701': '230', '020501': '760', '040605': '310', '051101': '330', '000101': '330', '861204': '750', '070601': '310', '080101': '310', '940208': '150', '890602': '215', '070905': '325', '060601': '150', '930704': '750', '030704': '760', '040607': '230', '920803': '310', '070802': '121', '861007': '570', '020403': '756', '890302': '760', '020416': '756', '930909': '530', '050402': '310', '010601': '510', '870202': '570', '900106': '750', '020401': '756', '070903': '121', '020404': '756', '070302': '100', '031203': '760', '890503': '750', '040604': '760'}
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# fullID[imagep] 910901_Bryan_100
# imagep 910901
# file_resize ['../datasets/personout/910901_Bryan_100/IMG_5759 001.png', '../datasets/personout/910901_Bryan_100/IMG_5656 001.png', '../datasets/personout/910901_Bryan_100/IMG_6222 001.png']
# file_resize[-1] ../datasets/personout/910901_Bryan_100/IMG_6222 001.png
# fullID[imagep] 070401_Alex_100
# imagep 070401
# file_resize ['../datasets/personout/070401_Alex_100/IMG_8090 001.png', '../datasets/personout/070401_Alex_100/IMG_5993 001.png']
# file_resize[-1] ../datasets/personout/070401_Alex_100/IMG_5993 001.png
# fullID[imagep] 861001_Ted_100
# imagep 861001
# file_resize ['../datasets/personout/861001_Ted_100/IMG_6007 001.png']
# file_resize[-1] ../datasets/personout/861001_Ted_100/IMG_6007 001.png
# fullID[imagep] 070302_Mei_100
# imagep 070302
# file_resize ['../datasets/personout/070302_Mei_100/IMG_5954 0001.png']
# file_resize[-1] ../datasets/personout/070302_Mei_100/IMG_5954 0001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# fullID[imagep] 960703_Sam_760
# imagep 960703
# file_resize ['../datasets/personout/960703_Sam_760/IMG_5788 001.png']
# file_resize[-1] ../datasets/personout/960703_Sam_760/IMG_5788 001.png
# fullID[imagep] 920705_Diego_760
# imagep 920705
# file_resize ['../datasets/personout/920705_Diego_760/IMG_5783 001.png']
# file_resize[-1] ../datasets/personout/920705_Diego_760/IMG_5783 001.png
# fullID[imagep] 020501_Forbes_760
# imagep 020501
# file_resize ['../datasets/personout/020501_Forbes_760/IMG_5850 001.png', '../datasets/personout/020501_Forbes_760/IMG_5849 001.png']
# file_resize[-1] ../datasets/personout/020501_Forbes_760/IMG_5849 001.png
# fullID[imagep] 030704_Vincent_760
# imagep 030704
# file_resize ['../datasets/personout/030704_Vincent_760/IMG_5790 001.png']
# file_resize[-1] ../datasets/personout/030704_Vincent_760/IMG_5790 001.png
# fullID[imagep] 890302_David_760
# imagep 890302
# file_resize ['../datasets/personout/890302_David_760/IMG_5857 001.png', '../datasets/personout/890302_David_760/IMG_5853 001.png', '../datasets/personout/890302_David_760/IMG_5957 001.png', '../datasets/personout/890302_David_760/IMG_5854 001.png']
# file_resize[-1] ../datasets/personout/890302_David_760/IMG_5854 001.png
# fullID[imagep] 031203_Mark_760
# imagep 031203
# file_resize ['../datasets/personout/031203_Mark_760/IMG_5994 001.png', '../datasets/personout/031203_Mark_760/IMG_5792 001.png']
# file_resize[-1] ../datasets/personout/031203_Mark_760/IMG_5792 001.png
# fullID[imagep] 040604_Allen_760
# imagep 040604
# file_resize ['../datasets/personout/040604_Allen_760/IMG_5786 001.png', '../datasets/personout/040604_Allen_760/IMG_5700 001.png']
# file_resize[-1] ../datasets/personout/040604_Allen_760/IMG_5700 001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# fullID[imagep] 910901_Bryan_100
# imagep 910901
# file_resize ['../datasets/personout/910901_Bryan_100/IMG_5759 001.png', '../datasets/personout/910901_Bryan_100/IMG_5656 001.png', '../datasets/personout/910901_Bryan_100/IMG_6222 001.png']
# file_resize[-1] ../datasets/personout/910901_Bryan_100/IMG_6222 001.png
# fullID[imagep] 070401_Alex_100
# imagep 070401
# file_resize ['../datasets/personout/070401_Alex_100/IMG_8090 001.png', '../datasets/personout/070401_Alex_100/IMG_5993 001.png']
# file_resize[-1] ../datasets/personout/070401_Alex_100/IMG_5993 001.png
# fullID[imagep] 861001_Ted_100
# imagep 861001
# file_resize ['../datasets/personout/861001_Ted_100/IMG_6007 001.png']
# file_resize[-1] ../datasets/personout/861001_Ted_100/IMG_6007 001.png
# fullID[imagep] 070302_Mei_100
# imagep 070302
# file_resize ['../datasets/personout/070302_Mei_100/IMG_5954 0001.png']
# file_resize[-1] ../datasets/personout/070302_Mei_100/IMG_5954 0001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# fullID[imagep] 960703_Sam_760
# imagep 960703
# file_resize ['../datasets/personout/960703_Sam_760/IMG_5788 001.png']
# file_resize[-1] ../datasets/personout/960703_Sam_760/IMG_5788 001.png
# fullID[imagep] 920705_Diego_760
# imagep 920705
# file_resize ['../datasets/personout/920705_Diego_760/IMG_5783 001.png']
# file_resize[-1] ../datasets/personout/920705_Diego_760/IMG_5783 001.png
# fullID[imagep] 020501_Forbes_760
# imagep 020501
# file_resize ['../datasets/personout/020501_Forbes_760/IMG_5850 001.png', '../datasets/personout/020501_Forbes_760/IMG_5849 001.png']
# file_resize[-1] ../datasets/personout/020501_Forbes_760/IMG_5849 001.png
# fullID[imagep] 030704_Vincent_760
# imagep 030704
# file_resize ['../datasets/personout/030704_Vincent_760/IMG_5790 001.png']
# file_resize[-1] ../datasets/personout/030704_Vincent_760/IMG_5790 001.png
# fullID[imagep] 890302_David_760
# imagep 890302
# file_resize ['../datasets/personout/890302_David_760/IMG_5857 001.png', '../datasets/personout/890302_David_760/IMG_5853 001.png', '../datasets/personout/890302_David_760/IMG_5957 001.png', '../datasets/personout/890302_David_760/IMG_5854 001.png']
# file_resize[-1] ../datasets/personout/890302_David_760/IMG_5854 001.png
# fullID[imagep] 031203_Mark_760
# imagep 031203
# file_resize ['../datasets/personout/031203_Mark_760/IMG_5994 001.png', '../datasets/personout/031203_Mark_760/IMG_5792 001.png']
# file_resize[-1] ../datasets/personout/031203_Mark_760/IMG_5792 001.png
# fullID[imagep] 040604_Allen_760
# imagep 040604
# file_resize ['../datasets/personout/040604_Allen_760/IMG_5786 001.png', '../datasets/personout/040604_Allen_760/IMG_5700 001.png']
# file_resize[-1] ../datasets/personout/040604_Allen_760/IMG_5700 001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# fullID[imagep] 910901_Bryan_100
# imagep 910901
# file_resize ['../datasets/personout/910901_Bryan_100/IMG_5759 001.png', '../datasets/personout/910901_Bryan_100/IMG_5656 001.png', '../datasets/personout/910901_Bryan_100/IMG_6222 001.png']
# file_resize[-1] ../datasets/personout/910901_Bryan_100/IMG_6222 001.png
# fullID[imagep] 070401_Alex_100
# imagep 070401
# file_resize ['../datasets/personout/070401_Alex_100/IMG_8090 001.png', '../datasets/personout/070401_Alex_100/IMG_5993 001.png']
# file_resize[-1] ../datasets/personout/070401_Alex_100/IMG_5993 001.png
# fullID[imagep] 861001_Ted_100
# imagep 861001
# file_resize ['../datasets/personout/861001_Ted_100/IMG_6007 001.png']
# file_resize[-1] ../datasets/personout/861001_Ted_100/IMG_6007 001.png
# fullID[imagep] 070302_Mei_100
# imagep 070302
# file_resize ['../datasets/personout/070302_Mei_100/IMG_5954 0001.png']
# file_resize[-1] ../datasets/personout/070302_Mei_100/IMG_5954 0001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# fullID[imagep] 960703_Sam_760
# imagep 960703
# file_resize ['../datasets/personout/960703_Sam_760/IMG_5788 001.png']
# file_resize[-1] ../datasets/personout/960703_Sam_760/IMG_5788 001.png
# fullID[imagep] 920705_Diego_760
# imagep 920705
# file_resize ['../datasets/personout/920705_Diego_760/IMG_5783 001.png']
# file_resize[-1] ../datasets/personout/920705_Diego_760/IMG_5783 001.png
# fullID[imagep] 020501_Forbes_760
# imagep 020501
# file_resize ['../datasets/personout/020501_Forbes_760/IMG_5850 001.png', '../datasets/personout/020501_Forbes_760/IMG_5849 001.png']
# file_resize[-1] ../datasets/personout/020501_Forbes_760/IMG_5849 001.png
# fullID[imagep] 030704_Vincent_760
# imagep 030704
# file_resize ['../datasets/personout/030704_Vincent_760/IMG_5790 001.png']
# file_resize[-1] ../datasets/personout/030704_Vincent_760/IMG_5790 001.png
# fullID[imagep] 890302_David_760
# imagep 890302
# file_resize ['../datasets/personout/890302_David_760/IMG_5857 001.png', '../datasets/personout/890302_David_760/IMG_5853 001.png', '../datasets/personout/890302_David_760/IMG_5957 001.png', '../datasets/personout/890302_David_760/IMG_5854 001.png']
# file_resize[-1] ../datasets/personout/890302_David_760/IMG_5854 001.png
# fullID[imagep] 031203_Mark_760
# imagep 031203
# file_resize ['../datasets/personout/031203_Mark_760/IMG_5994 001.png', '../datasets/personout/031203_Mark_760/IMG_5792 001.png']
# file_resize[-1] ../datasets/personout/031203_Mark_760/IMG_5792 001.png
# fullID[imagep] 040604_Allen_760
# imagep 040604
# file_resize ['../datasets/personout/040604_Allen_760/IMG_5786 001.png', '../datasets/personout/040604_Allen_760/IMG_5700 001.png']
# file_resize[-1] ../datasets/personout/040604_Allen_760/IMG_5700 001.png
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 2
# number 910901
# number 070401
# number 861001
# number 070302
# personq 910901
# persenID Bryan
# personq 070401
# persenID Alex
# personq 861001
# persenID Ted
# personq 070302
# persenID Mei
# dpartment 120
# line1 3
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 4
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 5
# number 940208
# number 060601
# personq 940208
# persenID Jerry
# personq 060601
# persenID Iona
# dpartment 220
# line1 6
# dpartment 223
# line1 7
# dpartment 310
# line1 8
# number 020412
# number 040605
# number 070601
# number 080101
# number 920803
# number 050402
# personq 020412
# persenID Robert
# personq 040605
# persenID Rick
# personq 070601
# persenID Ching
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# dpartment 325
# line1 9
# number 891001
# number 070905
# personq 891001
# persenID Willie
# personq 070905
# persenID Stanley
# dpartment 330
# line1 10
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 11
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 12
# number 070301
# number 050702
# number 861204
# number 930704
# number 900106
# number 890503
# personq 070301
# persenID William
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 900106
# persenID Danny
# personq 890503
# persenID Wayne
# dpartment 756
# line1 13
# number 040701
# number 020406
# number 060602
# number 020403
# number 020416
# number 020401
# number 020404
# personq 040701
# persenID Jackie
# personq 020406
# persenID James
# personq 060602
# persenID Eson
# personq 020403
# persenID Jerry
# personq 020416
# persenID Kay
# personq 020401
# persenID Ken
# personq 020404
# persenID Rala
# dpartment 760
# line1 14
# number 960703
# number 920705
# number 020501
# number 030704
# number 890302
# number 031203
# number 040604
# personq 960703
# persenID Sam
# personq 920705
# persenID Diego
# personq 020501
# persenID Forbes
# personq 030704
# persenID Vincent
# personq 890302
# persenID David
# personq 031203
# persenID Mark
# personq 040604
# persenID Allen
# dpartment 570
# line1 15
# number 861007
# number 870202
# personq 861007
# persenID Kuan
# personq 870202
# persenID R4Lai
# dpartment 160
# line1 16
# dpartment 510
# line1 17
# number 900211
# number 010601
# personq 900211
# persenID Carol
# personq 010601
# persenID Jessie
# dpartment 530
# line1 18
# number 050101
# number 930909
# personq 050101
# persenID PeiZhong
# personq 930909
# persenID Mandy

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# author:洪卫



import tkinter as tk  # 使用Tkinter前需要先导入
# from tkinter import ttk
# from PIL import ImageTk, Image 
import glob
dpartment=[100,120,121,150,220,223,310,325,330,350,750,756,760,570,160,510,530]

def read_train_object():
    train_name = open('/home/vincent/facenet/models/name.txt','r') 
    
    lines = train_name.readlines()
    count=0
    for a in lines:
        b=a.split('\n')
        lines[count]=b[0]
        count += 1
    train_name.close
    return lines


def person_pd_ID():
    allname=read_train_object()
    print(allname)
    name123=[]
    number123=[]
    pd123=[]
    for a in allname:
        print(a)
        all_23=a.split("_")
        print(all_23)
        number15=all_23[0]
        name15=all_23[1]
        pd15=all_23[2]
        number123.append(number15)
        name123.append(name15)
        pd123.append(pd15)

    print(name123)
    print(number123)
    print(pd123)

    persenID = dict(zip(number123, name123))
    pdID = dict(zip(number123, pd123))
    print(persenID)
    print(pdID)
    return number123,persenID,pdID 
          

def do_job():
    app3.destroy()
    app.destroy()
    app1 = tk.Frame(window)
#     app = tk.Frame(window)
#     app.grid()

#     app.grid_forget()
    #從資料夾抓取以建檔名稱
    filename=[]
    sourcefile=glob.glob(r'../datasets/personout/*')
    print('sourcefile',sourcefile)
    for a in sourcefile:
        finalname=a.split("/")
        filename.append(finalname[-1])
    print ('finalname',filename)
    print('len(filename',len(filename))
    line1=0
    
    for dpart in dpartment:
        
        print('dpartment',dpart)
        locals()['var'+str(dpart)]=tk.StringVar()
        locals()['var'+str(dpart)].set(str(dpart)+'部門:  ')
#         locals()['textLabel'+str(dpart)] = tk.Label(window,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12), width=30, height=2,justify = tk.LEFT)#显示文字内容 
        locals()['textLabel'+str(dpart)] = tk.Label(app1,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12),justify = tk.LEFT)#显示文字内容
        locals()['textLabel'+str(dpart)].grid(column=0, row=line1, sticky=tk.W) #自动对齐,side：方位
        
#         line1=line1+1
        print('line1',line1)
        gpart=[]
        for c,v in pdID.items():
            if str(v)==str(dpart):
                gpart.append(c)
                print('number',c)
        column01=1
        for personq in gpart:
            if len(gpart)<10:
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['var'+str(personq)]=tk.StringVar()
                locals()['var'+str(personq)].set(persenID[personq])
                locals()['textLabel'+str(personq)] = tk.Label(app1,textvariable=locals()['var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1
                if column01==len(gpart)-1:
                    line1=line1+1
                    
        line1=line1+2

        
        
    
    
#     for bdd in range(0,len(filename)):
#         print (bdd)
        

        
#         locals()['var'+str(bdd)]=tk.StringVar()
#         locals()['var'+str(bdd)].set(filename[bdd])
#         locals()['textLabel'+str(bdd)] = tk.Label(window,textvariable=locals()['var'+str(bdd)],justify = tk.LEFT)#显示文字内容 
#         locals()['textLabel'+str(bdd)].grid(column=int(bdd/8), row=(bdd*2)%6, sticky=tk.W) #自动对齐,side：方位
# #         locals()['textLabel'+str(bdd)].Scrollbar(window, orient = HORIZONTAL)
#         try:
#             file_resize=glob.glob(r'../datasets/personout/'+filename[bdd]+'/*001.png')
#         except:
#             file_resize=glob.glob(r'../datasets/personout/'+filename[bdd]+'/*.png')
    
#         print('file_resize',file_resize)
#         realname=file_resize[-1].split('/')
        
#         locals()['photo'+str(bdd)] = tk.PhotoImage(file=r'../datasets/personout/'+filename[bdd]+'/'+realname[-1])  #file：t图片路径
#         locals()['imgLabel'+str(bdd)]  = tk.Label(window,image=locals()['photo'+str(bdd)])#把图片整合到标签类中
# #         locals()['imgLabel'+str(bdd)].pack(side=tk.LEFT)#自动对齐
#         line1=line1+1
#         locals()['imgLabel'+str(bdd)].grid(column=int(bdd/8), row=(bdd*2+1)%6, sticky=tk.W)
# #         locals()['imgLabel'+str(bdd)].Scrollbar(window, orient = HORIZONTAL)
#     app1.grid()
    window.mainloop()
    

#     var = tk.StringVar()#储存文字的类
#     var.set("vincent\npd760")#设置文字
#     textLabel = tk.Label(window,textvariable=var,justify = tk.LEFT)#显示文字内容 
#     textLabel.pack(side=tk.LEFT)#自动对齐,side：方位
#     #创建一个图片管理类
# #     photo = tk.PhotoImage(file="/home/vincent/facenet/datasets/personout/920803_Gillian_310/IMG_9362 003.png")#file：t图片路径
# #     imgLabel = tk.Label(window,image=photo)#把图片整合到标签类中
# #     imgLabel.pack(side=tk.RIGHT)#自动对齐
#     photo = tk.PhotoImage(file="IMG_002.png")#file：t图片路径
#     imgLabel = tk.Label(window,image=photo)#把图片整合到标签类中
#     imgLabel.pack(side=tk.LEFT)#自动对齐
#     window.mainloop()

    

    

# 第5步，创建一个菜单栏，这里我们可以把他理解成一个容器，在窗口的上方



def do_job1():
  
    app.destroy()
    app1.destroy()
    app3 = tk.Frame(window)
    
        #從資料夾抓取以建檔名稱
    filename=[]
    sourcefile=glob.glob(r'../datasets/personout/*')
    print('sourcefile',sourcefile)
    for a in sourcefile:
        finalname=a.split("/")
        filename.append(finalname[-1])
    print ('finalname',filename)
    print('len(filename',len(filename))
    line1=0

    for dpart in dpartment:

        print('dpartment',dpart)
        locals()['var'+str(dpart)]=tk.StringVar()
        locals()['var'+str(dpart)].set(str(dpart)+'部門:  ')
    #         locals()['textLabel'+str(dpart)] = tk.Label(window,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12), width=30, height=2,justify = tk.LEFT)#显示文字内容 
        locals()['textLabel'+str(dpart)] = tk.Label(app3,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12),justify = tk.LEFT)#显示文字内容
        locals()['textLabel'+str(dpart)].grid(column=0, row=line1, sticky=tk.W) #自动对齐,side：方位

    #         line1=line1+1
        print('line1',line1)
        gpart=[]
        for c,v in pdID.items():
            if str(v)==str(dpart):
                gpart.append(c)
                print('number',c)
        column01=1
        for personq in gpart:
            if len(gpart)<10:
                print('personq',personq)
                print('persenID',persenID[personq])
                locals()['var'+str(personq)]=tk.StringVar()
                locals()['var'+str(personq)].set(persenID[personq])
                locals()['textLabel'+str(personq)] = tk.Label(app3,textvariable=locals()['var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
                locals()['textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
                column01=column01+1
    #                 if column01==len(gpart)-1:
    #                     line1=line1+1

        line1=line1+1 
        
    app3.grid()
    window.mainloop()
    
    
    

number123,persenID,pdID =person_pd_ID()

# #從資料夾抓取以建檔名稱
# filename=[]
# sourcefile=glob.glob(r'../datasets/personout/*')
# print('sourcefile',sourcefile)
# for a in sourcefile:
#     finalname=a.split("/")
#     filename.append(finalname[-1])
# print ('finalname',filename)



# 第1步，实例化object，建立窗口window
window = tk.Tk()
 
# 第2步，给窗口的可视化起名字
window.title('撼訊科技 門禁管理系統')
 
# 第3步，设定窗口的大小(长 * 宽)
window.geometry('800x600')  # 这里的乘是小x
 
# # 第4步，在图形界面上创建一个标签用以显示内容并放置
# l = tk.Label(window, text='           ', bg='green')
# # l.pack()
 
# 第10步，定义一个函数功能，用来代表菜单选项的功能，这里为了操作简单，定义的功能比较简单
# counter = 0

app = tk.Frame(window)
app.grid()


app1 = tk.Frame(window)
app1.grid()

app3 = tk.Frame(window)
app3.grid()


menubar = tk.Menu(window)

# 第6步，创建一个File菜单项（默认不下拉，下拉内容包括New，Open，Save，Exit功能项）
filemenu = tk.Menu(menubar, tearoff=0)
# 将上面定义的空菜单命名为File，放在菜单栏中，就是装入那个容器中
menubar.add_cascade(label='開始', menu=filemenu)

# 在File中加入New、Open、Save等小菜单，即我们平时看到的下拉菜单，每一个小菜单对应命令操作。
filemenu.add_command(label='員工資料建立', command=do_job)
filemenu.add_command(label='出缺勤管理', command=do_job1)
filemenu.add_command(label='後台管理', command=do_job)
filemenu.add_separator()    # 添加一条分隔线
filemenu.add_command(label='Exit', command=window.quit) # 用tkinter里面自带的quit()函数

# 第7步，创建一个Edit菜单项（默认不下拉，下拉内容包括Cut，Copy，Paste功能项）
editmenu = tk.Menu(menubar, tearoff=0)
# 将上面定义的空菜单命名为 Edit，放在菜单栏中，就是装入那个容器中
menubar.add_cascade(label='執行', menu=editmenu)

# 同样的在 Edit 中加入Cut、Copy、Paste等小命令功能单元，如果点击这些单元, 就会触发do_job的功能
editmenu.add_command(label='門禁系統啟動', command=do_job)
editmenu.add_command(label='出缺勤紀錄日報表', command=do_job)
editmenu.add_command(label='陌生人管理', command=do_job)

# 第8步，创建第二级菜单，即菜单项里面的菜单
submenu = tk.Menu(filemenu) # 和上面定义菜单一样，不过此处实在File上创建一个空的菜单
filemenu.add_cascade(label='Import', menu=submenu, underline=0) # 给放入的菜单submenu命名为Import

# 第9步，创建第三级菜单命令，即菜单项里面的菜单项里面的菜单命令（有点拗口，笑~~~）
submenu.add_command(label='Submenu_1', command=do_job)   # 这里和上面创建原理也一样，在Import菜单项中加入一个小菜单命令Submenu_1

# 第11步，创建菜单栏完成后，配置让菜单栏menubar显示出来
window.config(menu=menubar)




#從資料夾抓取以建檔名稱
filename=[]
sourcefile=glob.glob(r'../datasets/personout/*')
print('sourcefile',sourcefile)
for a in sourcefile:
    finalname=a.split("/")
    filename.append(finalname[-1])
print ('finalname',filename)
print('len(filename',len(filename))
line1=0

for dpart in dpartment:

    print('dpartment',dpart)
    locals()['var'+str(dpart)]=tk.StringVar()
    locals()['var'+str(dpart)].set(str(dpart)+'部門:  ')
#         locals()['textLabel'+str(dpart)] = tk.Label(window,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12), width=30, height=2,justify = tk.LEFT)#显示文字内容 
    locals()['textLabel'+str(dpart)] = tk.Label(app,textvariable=locals()['var'+str(dpart)], bg='green', font=('Arial', 12),justify = tk.LEFT)#显示文字内容
    locals()['textLabel'+str(dpart)].grid(column=0, row=line1, sticky=tk.W) #自动对齐,side：方位

#         line1=line1+1
    print('line1',line1)
    gpart=[]
    for c,v in pdID.items():
        if str(v)==str(dpart):
            gpart.append(c)
            print('number',c)
    column01=1
    for personq in gpart:
        if len(gpart)<10:
            print('personq',personq)
            print('persenID',persenID[personq])
            locals()['var'+str(personq)]=tk.StringVar()
            locals()['var'+str(personq)].set(persenID[personq])
            locals()['textLabel'+str(personq)] = tk.Label(app,textvariable=locals()['var'+str(personq)], font=('Arial', 12),justify = tk.LEFT)#显示文字内容 
            locals()['textLabel'+str(personq)].grid(column=column01, row=line1, sticky=tk.W) #自动对齐,side：方位
            column01=column01+1
#                 if column01==len(gpart)-1:
#                     line1=line1+1

    line1=line1+1 



# 第12步，主窗口循环显示
window.mainloop()
# Out:
# ['000101_Andrew_330', '010601_Jessie_510', '020401_Ken_756', '020403_Jerry_756', '020404_Rala_756', '020406_James_756', '020411_Richard_330', '020412_Robert_310', '020416_Kay_756', '020501_Forbes_760', '030704_Vincent_760', '031203_Mark_760', '040604_Allen_760', '040605_Rick_310', '040607_Nicolaes_230', '040701_Jackie_756', '050101_PeiZhong_530', '050402_Catherine_310', '050702_Peter_750', '051101_Jacky_330', '060402_Abby_350', '060601_Iona_150', '060602_Eson_756', '070301_William_750', '070302_Mei_100', '070401_Alex_100', '070601_Ching_310', '070802_Jacky_121', '070903_Tony_121', '070905_Stanley_325', '080101_Fiona_310', '861001_Ted_100', '861007_Kuan_570', '861204_Freeman_750', '870202_R4Lai_570', '890302_David_760', '890503_Wayne_750', '890602_Willy_215', '891001_Willie_325', '900106_Danny_750', '900211_Carol_510', '910901_Bryan_100', '920502_Kelin_350', '920705_Diego_760', '920803_Gillian_310', '921003_Vinie_120', '930704_Jimmy_750', '930909_Mandy_530', '940204_Vivi_215', '940208_Jerry_150', '960701_Vado_230', '960703_Sam_760']
# 000101_Andrew_330
# ['000101', 'Andrew', '330']
# 010601_Jessie_510
# ['010601', 'Jessie', '510']
# 020401_Ken_756
# ['020401', 'Ken', '756']
# 020403_Jerry_756
# ['020403', 'Jerry', '756']
# 020404_Rala_756
# ['020404', 'Rala', '756']
# 020406_James_756
# ['020406', 'James', '756']
# 020411_Richard_330
# ['020411', 'Richard', '330']
# 020412_Robert_310
# ['020412', 'Robert', '310']
# 020416_Kay_756
# ['020416', 'Kay', '756']
# 020501_Forbes_760
# ['020501', 'Forbes', '760']
# 030704_Vincent_760
# ['030704', 'Vincent', '760']
# 031203_Mark_760
# ['031203', 'Mark', '760']
# 040604_Allen_760
# ['040604', 'Allen', '760']
# 040605_Rick_310
# ['040605', 'Rick', '310']
# 040607_Nicolaes_230
# ['040607', 'Nicolaes', '230']
# 040701_Jackie_756
# ['040701', 'Jackie', '756']
# 050101_PeiZhong_530
# ['050101', 'PeiZhong', '530']
# 050402_Catherine_310
# ['050402', 'Catherine', '310']
# 050702_Peter_750
# ['050702', 'Peter', '750']
# 051101_Jacky_330
# ['051101', 'Jacky', '330']
# 060402_Abby_350
# ['060402', 'Abby', '350']
# 060601_Iona_150
# ['060601', 'Iona', '150']
# 060602_Eson_756
# ['060602', 'Eson', '756']
# 070301_William_750
# ['070301', 'William', '750']
# 070302_Mei_100
# ['070302', 'Mei', '100']
# 070401_Alex_100
# ['070401', 'Alex', '100']
# 070601_Ching_310
# ['070601', 'Ching', '310']
# 070802_Jacky_121
# ['070802', 'Jacky', '121']
# 070903_Tony_121
# ['070903', 'Tony', '121']
# 070905_Stanley_325
# ['070905', 'Stanley', '325']
# 080101_Fiona_310
# ['080101', 'Fiona', '310']
# 861001_Ted_100
# ['861001', 'Ted', '100']
# 861007_Kuan_570
# ['861007', 'Kuan', '570']
# 861204_Freeman_750
# ['861204', 'Freeman', '750']
# 870202_R4Lai_570
# ['870202', 'R4Lai', '570']
# 890302_David_760
# ['890302', 'David', '760']
# 890503_Wayne_750
# ['890503', 'Wayne', '750']
# 890602_Willy_215
# ['890602', 'Willy', '215']
# 891001_Willie_325
# ['891001', 'Willie', '325']
# 900106_Danny_750
# ['900106', 'Danny', '750']
# 900211_Carol_510
# ['900211', 'Carol', '510']
# 910901_Bryan_100
# ['910901', 'Bryan', '100']
# 920502_Kelin_350
# ['920502', 'Kelin', '350']
# 920705_Diego_760
# ['920705', 'Diego', '760']
# 920803_Gillian_310
# ['920803', 'Gillian', '310']
# 921003_Vinie_120
# ['921003', 'Vinie', '120']
# 930704_Jimmy_750
# ['930704', 'Jimmy', '750']
# 930909_Mandy_530
# ['930909', 'Mandy', '530']
# 940204_Vivi_215
# ['940204', 'Vivi', '215']
# 940208_Jerry_150
# ['940208', 'Jerry', '150']
# 960701_Vado_230
# ['960701', 'Vado', '230']
# 960703_Sam_760
# ['960703', 'Sam', '760']
# ['Andrew', 'Jessie', 'Ken', 'Jerry', 'Rala', 'James', 'Richard', 'Robert', 'Kay', 'Forbes', 'Vincent', 'Mark', 'Allen', 'Rick', 'Nicolaes', 'Jackie', 'PeiZhong', 'Catherine', 'Peter', 'Jacky', 'Abby', 'Iona', 'Eson', 'William', 'Mei', 'Alex', 'Ching', 'Jacky', 'Tony', 'Stanley', 'Fiona', 'Ted', 'Kuan', 'Freeman', 'R4Lai', 'David', 'Wayne', 'Willy', 'Willie', 'Danny', 'Carol', 'Bryan', 'Kelin', 'Diego', 'Gillian', 'Vinie', 'Jimmy', 'Mandy', 'Vivi', 'Jerry', 'Vado', 'Sam']
# ['000101', '010601', '020401', '020403', '020404', '020406', '020411', '020412', '020416', '020501', '030704', '031203', '040604', '040605', '040607', '040701', '050101', '050402', '050702', '051101', '060402', '060601', '060602', '070301', '070302', '070401', '070601', '070802', '070903', '070905', '080101', '861001', '861007', '861204', '870202', '890302', '890503', '890602', '891001', '900106', '900211', '910901', '920502', '920705', '920803', '921003', '930704', '930909', '940204', '940208', '960701', '960703']
# ['330', '510', '756', '756', '756', '756', '330', '310', '756', '760', '760', '760', '760', '310', '230', '756', '530', '310', '750', '330', '350', '150', '756', '750', '100', '100', '310', '121', '121', '325', '310', '100', '570', '750', '570', '760', '750', '215', '325', '750', '510', '100', '350', '760', '310', '120', '750', '530', '215', '150', '230', '760']
# {'040607': 'Nicolaes', '070601': 'Ching', '890602': 'Willy', '920502': 'Kelin', '910901': 'Bryan', '020401': 'Ken', '900106': 'Danny', '020501': 'Forbes', '920705': 'Diego', '050702': 'Peter', '020416': 'Kay', '861204': 'Freeman', '010601': 'Jessie', '930704': 'Jimmy', '020411': 'Richard', '070905': 'Stanley', '900211': 'Carol', '020406': 'James', '030704': 'Vincent', '031203': 'Mark', '070802': 'Jacky', '051101': 'Jacky', '070903': 'Tony', '890503': 'Wayne', '861001': 'Ted', '890302': 'David', '070401': 'Alex', '040605': 'Rick', '040701': 'Jackie', '060402': 'Abby', '960703': 'Sam', '080101': 'Fiona', '060602': 'Eson', '870202': 'R4Lai', '060601': 'Iona', '000101': 'Andrew', '020404': 'Rala', '070302': 'Mei', '040604': 'Allen', '070301': 'William', '861007': 'Kuan', '920803': 'Gillian', '960701': 'Vado', '050402': 'Catherine', '020412': 'Robert', '940204': 'Vivi', '921003': 'Vinie', '930909': 'Mandy', '050101': 'PeiZhong', '020403': 'Jerry', '891001': 'Willie', '940208': 'Jerry'}
# {'040607': '230', '070601': '310', '890602': '215', '920502': '350', '910901': '100', '020401': '756', '900106': '750', '020501': '760', '920705': '760', '050702': '750', '020416': '756', '861204': '750', '010601': '510', '930704': '750', '020411': '330', '070905': '325', '900211': '510', '020406': '756', '030704': '760', '031203': '760', '070802': '121', '051101': '330', '070903': '121', '890503': '750', '861001': '100', '890302': '760', '070401': '100', '040605': '310', '040701': '756', '060402': '350', '960703': '760', '080101': '310', '060602': '756', '870202': '570', '060601': '150', '000101': '330', '020404': '756', '070302': '100', '040604': '760', '070301': '750', '861007': '570', '920803': '310', '960701': '230', '050402': '310', '020412': '310', '940204': '215', '921003': '120', '930909': '530', '050101': '530', '020403': '756', '891001': '325', '940208': '150'}
# sourcefile ['../datasets/personout/920502_Kelin_350', '../datasets/personout/031203_Mark_760', '../datasets/personout/070401_Alex_100', '../datasets/personout/020501_Forbes_760', '../datasets/personout/051101_Jacky_330', '../datasets/personout/030704_Vincent_760', '../datasets/personout/910901_Bryan_100', '../datasets/personout/040605_Rick_310', '../datasets/personout/920803_Gillian_310', '../datasets/personout/000101_Andrew_330', '../datasets/personout/020406_James_756', '../datasets/personout/060602_Eson_756', '../datasets/personout/020403_Jerry_756', '../datasets/personout/070802_Jacky_121', '../datasets/personout/900211_Carol_510', '../datasets/personout/890602_Willy_215', '../datasets/personout/930704_Jimmy_750', '../datasets/personout/020411_Richard_330', '../datasets/personout/010601_Jessie_510', '../datasets/personout/060402_Abby_350', '../datasets/personout/870202_R4Lai_570', '../datasets/personout/080101_Fiona_310', '../datasets/personout/070302_Mei_100', '../datasets/personout/920705_Diego_760', '../datasets/personout/940208_Jerry_150', '../datasets/personout/070905_Stanley_325', '../datasets/personout/040607_Nicolaes_230', '../datasets/personout/070601_Ching_310', '../datasets/personout/060601_Iona_150', '../datasets/personout/960703_Sam_760', '../datasets/personout/861204_Freeman_750', '../datasets/personout/020404_Rala_756', '../datasets/personout/040604_Allen_760', '../datasets/personout/020412_Robert_310', '../datasets/personout/921003_Vinie_120', '../datasets/personout/020401_Ken_756', '../datasets/personout/900106_Danny_750', '../datasets/personout/070301_William_750', '../datasets/personout/020416_Kay_756', '../datasets/personout/890302_David_760', '../datasets/personout/940204_Vivi_215', '../datasets/personout/891001_Willie_325', '../datasets/personout/861007_Kuan_570', '../datasets/personout/070903_Tony_121', '../datasets/personout/930909_Mandy_530', '../datasets/personout/050702_Peter_750', '../datasets/personout/050101_PeiZhong_530', '../datasets/personout/050402_Catherine_310', '../datasets/personout/890503_Wayne_750', '../datasets/personout/040701_Jackie_756', '../datasets/personout/960701_Vado_230', '../datasets/personout/861001_Ted_100']
# finalname ['920502_Kelin_350', '031203_Mark_760', '070401_Alex_100', '020501_Forbes_760', '051101_Jacky_330', '030704_Vincent_760', '910901_Bryan_100', '040605_Rick_310', '920803_Gillian_310', '000101_Andrew_330', '020406_James_756', '060602_Eson_756', '020403_Jerry_756', '070802_Jacky_121', '900211_Carol_510', '890602_Willy_215', '930704_Jimmy_750', '020411_Richard_330', '010601_Jessie_510', '060402_Abby_350', '870202_R4Lai_570', '080101_Fiona_310', '070302_Mei_100', '920705_Diego_760', '940208_Jerry_150', '070905_Stanley_325', '040607_Nicolaes_230', '070601_Ching_310', '060601_Iona_150', '960703_Sam_760', '861204_Freeman_750', '020404_Rala_756', '040604_Allen_760', '020412_Robert_310', '921003_Vinie_120', '020401_Ken_756', '900106_Danny_750', '070301_William_750', '020416_Kay_756', '890302_David_760', '940204_Vivi_215', '891001_Willie_325', '861007_Kuan_570', '070903_Tony_121', '930909_Mandy_530', '050702_Peter_750', '050101_PeiZhong_530', '050402_Catherine_310', '890503_Wayne_750', '040701_Jackie_756', '960701_Vado_230', '861001_Ted_100']
# len(filename 52
# dpartment 100
# line1 0
# number 910901
# number 861001
# number 070401
# number 070302
# personq 910901
# persenID Bryan
# personq 861001
# persenID Ted
# personq 070401
# persenID Alex
# personq 070302
# persenID Mei
# dpartment 120
# line1 1
# number 921003
# personq 921003
# persenID Vinie
# dpartment 121
# line1 2
# number 070802
# number 070903
# personq 070802
# persenID Jacky
# personq 070903
# persenID Tony
# dpartment 150
# line1 3
# number 060601
# number 940208
# personq 060601
# persenID Iona
# personq 940208
# persenID Jerry
# dpartment 220
# line1 4
# dpartment 223
# line1 5
# dpartment 310
# line1 6
# number 070601
# number 040605
# number 080101
# number 920803
# number 050402
# number 020412
# personq 070601
# persenID Ching
# personq 040605
# persenID Rick
# personq 080101
# persenID Fiona
# personq 920803
# persenID Gillian
# personq 050402
# persenID Catherine
# personq 020412
# persenID Robert
# dpartment 325
# line1 7
# number 070905
# number 891001
# personq 070905
# persenID Stanley
# personq 891001
# persenID Willie
# dpartment 330
# line1 8
# number 020411
# number 051101
# number 000101
# personq 020411
# persenID Richard
# personq 051101
# persenID Jacky
# personq 000101
# persenID Andrew
# dpartment 350
# line1 9
# number 920502
# number 060402
# personq 920502
# persenID Kelin
# personq 060402
# persenID Abby
# dpartment 750
# line1 10
# number 900106
# number 050702
# number 861204
# number 930704
# number 890503
# number 070301
# personq 900106
# persenID Danny
# personq 050702
# persenID Peter
# personq 861204
# persenID Freeman
# personq 930704
# persenID Jimmy
# personq 890503
# persenID Wayne
# personq 070301
# persenID William
# dpartment 756
# line1 11
# number 020401
# number 020416
# number 020406
# number 040701
# number 060602
# number 020404
# number 020403
# personq 020401
# persenID Ken
# personq 020416
# persenID Kay
# personq 020406
# persenID James
# personq 040701
# persenID Jackie
# personq 060602
# persenID Eson
# personq 020404
# persenID Rala
# personq 020403
# persenID Jerry
# dpartment 760
# line1 12
# number 020501
# number 920705
# number 030704
# number 031203
# number 890302
# number 960703
# number 040604
# personq 020501
# persenID Forbes
# personq 920705
# persenID Diego
# personq 030704
# persenID Vincent
# personq 031203
# persenID Mark
# personq 890302
# persenID David
# personq 960703
# persenID Sam
# personq 040604
# persenID Allen
# dpartment 570
# line1 13
# number 870202
# number 861007
# personq 870202
# persenID R4Lai
# personq 861007
# persenID Kuan
# dpartment 160
# line1 14
# dpartment 510
# line1 15
# number 010601
# number 900211
# personq 010601
# persenID Jessie
# personq 900211
# persenID Carol
# dpartment 530
# line1 16
# number 930909
# number 050101
# personq 930909
# persenID Mandy
# personq 050101
# persenID PeiZhong

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# author:洪卫

import tkinter as tk  # 使用Tkinter前需要先导入
import tkinter.messagebox  # 要使用messagebox先要导入模块

# 第1步，实例化object，建立窗口window
window = tk.Tk()

# 第2步，给窗口的可视化起名字
window.title('My Window')

# 第3步，设定窗口的大小(长 * 宽)
window.geometry('500x300')  # 这里的乘是小x

# 第5步，定义触发函数功能
def hit_me():
    tkinter.messagebox.showinfo(title='Hi', message='你好！')              # 提示信息对话窗
    # tkinter.messagebox.showwarning(title='Hi', message='有警告！')       # 提出警告对话窗
    # tkinter.messagebox.showerror(title='Hi', message='出错了！')         # 提出错误对话窗
    # print(tkinter.messagebox.askquestion(title='Hi', message='你好！'))  # 询问选择对话窗return 'yes', 'no'
    # print(tkinter.messagebox.askyesno(title='Hi', message='你好！'))     # return 'True', 'False'
    # print(tkinter.messagebox.askokcancel(title='Hi', message='你好！'))  # return 'True', 'False'

# 第4步，在图形界面上创建一个标签用以显示内容并放置
tk.Button(window, text='hit me', bg='green', font=('Arial', 14), command=hit_me).pack()

# 第6步，主窗口循环显示
window.mainloop()

# %%
import tkinter as tk

root = tk.Toplevel()

frame1 = tk.Frame(root)#这是上面的框架
frame2 = tk.Frame(root)#这是下面的框架


var = tk.StringVar()#储存文字的类
var.set("vincent\npd760")#设置文字

#创建一个标签类, [justify]:对齐方式，[frame]所属框架
textLabel = tk.Label(frame1,textvariable=var,justify = tk.LEFT)#显示文字内容 
textLabel.pack(side=tk.LEFT)#自动对齐,side：方位

 

#创建一个图片管理类
photo = tk.PhotoImage(file="/home/vincent/facenet/real-time-deep-face-recognition/IMG_002.png")#file：t图片路径
imgLabel = tk.Label(frame1,image=photo)#把图片整合到标签类中
imgLabel.pack(side=tk.RIGHT)#自动对齐


def callback():#触发的函数
    var.set("你还真按了")#设置文字

#[frame]所属框架 ，text 文字内容 command：触发方法
theButton = tk.Button(frame2,text="我是下面的按钮",command=callback)
theButton.pack()#自动对齐

 

frame1.pack(padx=10,pady=10)#上框架对齐
frame2.pack(padx=10,pady=10)#下框架对齐


tk.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def callbackFunc():
    resultString.set("{} - {}".format(landString.get(),
                                      cityString.get()))
     
app = tk.Tk() 
app.geometry('200x100')

labelLand = tk.Label(app,
                    text = "Country")
labelLand.grid(column=0, row=0, sticky=tk.W)
labelCity = tk.Label(app,
                    text = "City")
labelCity.grid(column=0, row=1, sticky=tk.W)

landString = tk.StringVar()
cityString = tk.StringVar()
entryLand = tk.Entry(app, width=20, textvariable=landString)
entryCity = tk.Entry(app, width=20, textvariable=cityString)

entryLand.grid(column=1, row=0, padx=10)
entryCity.grid(column=1, row=1, padx=10)

resultButton = tk.Button(app, text = 'Get Result',
                         command=callbackFunc)

resultButton.grid(column=0, row=2, pady=10, sticky=tk.W)

resultString=tk.StringVar()
resultLabel = tk.Label(app, textvariable=resultString)
resultLabel.grid(column=1, row=2, padx=10, sticky=tk.W)

app.mainloop()

# %%
# -*- coding: utf-8 -*- 

import tkinter as tk

root = tk.Tk()

class mainpage(object):
    def __init__(self, master=None):
        self.root = master 
        self.page = tk.Frame(self.root) 
        self.page.pack()
        self.Button = tk.Button(self.page, text=u'跳頁',command=self.secpage) 
        self.Button.grid(column=0,row=0) 

    def secpage(self):
        self.page.destroy()
        secondpage(self.root)
    
class secondpage(object):
    def __init__(self, master=None):
        self.root = master
        self.page = tk.Frame(self.root)
        self.page.pack()
        self.Button = tk.Button(self.page, text=u'主頁',command=self.mainpage) 
        self.Button.grid(column=0,row=0) 
        
        self.var = tk.StringVar()#储存文字的类
        self.var.set("vincent\npd760")#设置文字
        self.textLabel = tk.Label(self.page,textvariable=self.var,justify = tk.LEFT)#显示文字内容 
        self.textLabel.grid(column=1,row=0) #自动对齐,side：方位
        
    def mainpage(self):
        self.page.destroy()
        mainpage(self.root)

        
mainpage(root)
root.mainloop()

# %%
import tkinter as tk
from random import shuffle

participants = [
    "Fred Flintstone", "Barney Rubble", "Wilma Flintstone", "Betty Rubble"
]

def get_pairings():
    '''for simulation purposes, this simply randomizes the participants'''
    global participants

    # see http://stackoverflow.com/a/23286332/7432
    shuffle(participants)
    return zip(*[iter(participants)]*2)


def reset():
    '''Reset the list of participants'''
    for child in app.winfo_children():
        child.destroy()

    for players in get_pairings():
        label = tk.Label(app, text="%s vs. %s" % players)
        label.grid()

root = tk.Tk()

root.title("Tournament")

app = tk.Frame(root)
app.grid()

button=tk.Button(root,text="Next Round", command=reset)
button.grid()

# this sets up the first round
reset()

root.mainloop()

# %%
from tkinter import *

class Application:

    def __init__(self, master):
        self.master = master

        self.new_switch_on = False
        self.main_switch_on = False

        self.create_main_frame()

    def create_main_frame(self): # new name
        if self.new_switch_on == True:
            self.new_frame.destroy()

        self.new_switch_on = False
        self.main_switch_on = True

        self.main_frame = Frame(self.master, width = 200, height = 100)

        Label(self.main_frame, text = 'Main Frame').pack()
        Button(self.main_frame, text = 'Next', command = self.create_new_frame).pack()  # new name

        self.main_frame.pack()

    def create_new_frame(self): # new name
        if self.main_switch_on == True:
            self.main_frame.destroy()

        self.main_switch_on = False
        self.new_switch_on = True

        self.new_frame = Frame(self.master, width = 400, height = 200)

        Label(self.new_frame, text='New Frame').pack()
        Button(self.new_frame, text='Back', command=self.create_main_frame).pack()  # new name

        self.new_frame.pack()


root = Tk()
root.geometry('-1+1')

app = Application(root)

root.mainloop()

# %%
# import subprocess
# # 目录
# subprocess.Popen(r'explorer "/home/vincent/facenet/datasets/personout/000101_Andrew_330/IMG_5959 002.png" ')
# # 文件
# subprocess.Popen(r'explorer /select,"C:\path\of\file"')

import os

os.system('start explorer '+'/home/vincent/facenet/datasets/personout/000101_Andrew_330/')
# Out:
# 256

# %%
import subprocess
# 目录
subprocess.Popen(r'explorer "/home/vincent/facenet/datasets/personout/000101_Andrew_330/"')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-6996da9d840f> in <module>()
#       1 import subprocess
#       2 # 目录
# ----> 3 subprocess.Popen(r'explorer "/home/vincent/facenet/datasets/personout/000101_Andrew_330/"')
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'explorer "/home/vincent/facenet/datasets/personout/000101_Andrew_330/"'
